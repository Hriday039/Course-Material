# %%
import numpy as np

# %% [markdown]
# # Matplotlib
#
# Matplotlib is the "grandfather" library of data visualization with Python. It was created by John Hunter. He created it to try to replicate MatLab's (another programming language) plotting capabilities in Python. So if you happen to be familiar with matlab, matplotlib will feel natural to you.
#
# It is an excellent 2D and 3D graphics library for generating scientific figures.
#
# Some of the major Pros of Matplotlib are:
#
# * Generally easy to get started for simple plots
# * Support for custom labels and texts
# * Great control of every element in a figure
# * High-quality output in many formats
# * Very customizable in general
#
# Matplotlib allows you to create reproducible figures programmatically. Let's learn how to use it! Before continuing this lecture, I encourage you just to explore the official Matplotlib web page: http://matplotlib.org/
#
# ## Installation
#
# You'll need to install matplotlib first with either:
#
#     conda install matplotlib
# or
#
#     pip install matplotlib
#
# ## Importing
#
# Import the `matplotlib.pyplot` module under the name `plt` :

# %%
import matplotlib.pyplot as plt

# %%
# You'll also need to use this line to see plots in the notebook:
# %matplotlib inline

# %% [markdown]
# # Line Chart

# %%
# Equation of the line
x = np.linspace(0, 5, 11)
# Calculating value of the y
y = x ** 2

# plotting the line
# 'r' is the color red
plt.plot(x, y, 'r') 
# adding X-axis title
plt.xlabel('X Axis Title Here')
# adding Y-axis title
plt.ylabel('Y Axis Title Here')
# addin plot title
plt.title('String Title Here')
# to show the plot
plt.show()

# %%
# plt.subplot(nrows, ncols, plot_number)
plt.subplot(1,2,1)
# More on color options later
plt.plot(x, y, 'r--') 
plt.subplot(1,2,2)
plt.plot(y, x, 'g*-');

# %%
# different types of theme

plt.style.use('seaborn-dark')
#plt.style.use('bmh')
#plt.style.use('Solarize_Light2')
#plt.style.use('dark_background')

# %%
# Equation of the line
x = np.linspace(0, 5, 11)
# Calculating value of the y
y = x ** 2

# plotting the line
# 'r' is the color red
plt.plot(x, y, 'r') 
# adding X-axis title
plt.xlabel('X Axis Title Here')
# adding Y-axis title
plt.ylabel('Y Axis Title Here')
# addin plot title
plt.title('String Title Here')
# to save the plot
plt.savefig('foo.png')
# to show the plot
plt.show()

# %%
plt.plot(x, y, label='Line 1')
plt.plot(y, x, label='Line 2')
plt.show()

# %% [markdown]
# # Histogram

# %% [markdown]
# A histogram is a plot that lets you discover, and show, the underlying frequency distribution (shape) of a set of continuous data. This allows the inspection of the data for its underlying distribution (e.g., normal distribution), outliers, skewness, etc.

# %%
# this is to generate data
data = np.random.randint(1, 11, 100)
# this is to generate histogram
plt.hist(data)
plt.xlabel('X Axis Title Here')
plt.ylabel('Y Axis Title Here')
plt.title('Image Title Here')
plt.show()

# %%
langs = ['C', 'C++', 'Java', 'Python', 'PHP']
students = [23,17,35,29,12]
plt.bar(langs, students)
plt.xlabel('X Axis Title Here')
plt.ylabel('Y Axis Title Here')
plt.title('Image Title Here')
plt.show()

# %% [markdown]
# # The Difference Between Bar Charts and Histograms
#
# Here is the main difference between bar charts and histograms. With bar charts, each column represents a group defined by a categorical variable; and with histograms, each column represents a group defined by a continuous, quantitative variable.
#
# One implication of this distinction: it can be appropriate to talk about the skewness of a histogram; that is, the tendency of the observations to fall more on the low end or the high end of the X axis.
#
# With bar charts, however, the X axis does not have a low end or a high end; because the labels on the X axis are categorical - not quantitative. As a result, it is not appropriate to comment on the skewness of a bar chart.

# %% [markdown]
# To see the different features of histogram, visit this link https://www.datacamp.com/community/tutorials/histograms-matplotlib
#
# To see different features of barchart, visit this link https://benalexkeen.com/bar-charts-in-matplotlib/

# %% [markdown]
# # Scatter Plot
#
# A scatter chart works best when comparing large numbers of data points without regard to time. This is a very powerful type of chart and good when your are trying to show the relationship between two variables (x and y axis), for example a person's weight and height.

# %%
x = np.random.randint(1, 100, 20)
y = np.random.randint(1, 100, 20)

plt.figure(figsize=(17,5)) 
plt.scatter(x,y)
plt.xlabel('X Axis Title Here')
plt.ylabel('Y Axis Title Here')
plt.title('String Title Here')
plt.show()

# %% [markdown]
# ## Pie Chart
#
# Pie charts are generally used to show percentage or proportional data and usually the percentage represented by each category is provided next to the corresponding slice of pie. Pie charts are good for displaying data for around 6 categories or fewer.

# %%
# adjustig figure size
plt.figure(figsize=(17,5)) 
# labels 
labels = ['Frogs', 'Hogs', 'Dogs', 'Logs']
# ratio
sizes = [15, 30.4, 44.6, 10]
# only "explode" the 2nd slice (i.e. 'Hogs')
explode = (0, 0.1, 0, 0)  

plt.pie(sizes, explode=explode, labels=labels, autopct='%.2f%%', startangle=90)
plt.title('String Title Here')
plt.show()

# %% [markdown]
# # Seaborn
#
# Seaborn is used for more interactive and complex plot
#
# ## Installation
#
# You'll need to install seaborn first with either:
#
#     conda install -c anaconda seaborn
#
# or
#
#     pip install seaborn

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv(r'tempYearly.csv')

# %%
df.head()
# Out:
#    Temperature  Year  Rainfall
# 0        16.99  1956      1.01
# 1        10.34  1957      1.66
# 2        21.01  1958      3.50
# 3        23.68  1959      3.31
# 4        24.59  1960      3.61

# %%
#To increase width of plot
sns.set(rc={'figure.figsize':(12,6)})
sns.scatterplot(x = 'Year',
               y = 'Temperature',
               data = df)
plt.show()

# %%
#regplot to see regression line
sns.set(rc={'figure.figsize':(12,6)})
sns.regplot(x = 'Year',
               y = 'Temperature',
               data = df)
plt.show()

# %%
#We will draw a joint plot which will get scatterplot in middle and histograms on the side
sns.jointplot("Rainfall",
             "Temperature",
              data = df
             )
plt.show()
# Out:
# C:\Users\kucse\anaconda3\envs\coel\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# In the above jointplot:
# ----------------------------------
#
# Scatterplot can show us outliers, we can imagine a regression line and see the outliers
#
# Histograms can show us the distibution of the data

# %%
sns.jointplot("Rainfall",
             "Temperature",
              data = df,
              kind = "hex"   #Hexagram to visualize it abit better
             )
plt.show()
# Out:
# C:\Users\kucse\anaconda3\envs\coel\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot("Rainfall",
             "Temperature",
              data = df,
              kind = "reg"   #Regression Line, so we can see a possible +ve correlation
             )
plt.show()
# Out:
# C:\Users\kucse\anaconda3\envs\coel\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # IPYMPL in Jupyter Lab
#
#
# To enable interactive visualization backend, you only need to use the Jupyter magic command:
#
#     %matplotlib widget
#
# ## Installation
#
# You'll need to install IPYML first with either:
#
#     conda install -c conda-forge ipympl
#
# or
#
#     pip install ipympl

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = "https://raw.githubusercontent.com/plotly/datasets/master/tips.csv"
df = pd.read_csv(url)

# %%
df.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# %matplotlib notebook

# %%
# %matplotlib widget

# Matplotlib Scatter Plot
plt.scatter("total_bill", "tip", data=df)
plt.xlabel("Total Bill")
plt.ylabel("Tip")
plt.show()
# Out:
# Warning: Cannot change to a different GUI toolkit: widget. Using notebook instead.
# <img src="data:image/png;base64,..." width="640">

# %%
#%matplotlib widget

df.plot(kind="line")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>
